# %%
import sys
sys.path.append("..")

# %%
from src.split import karpathy_split, save_split

# %%
train, val, test = karpathy_split()
print(f"Train set: {train[:5]}")
print(f"Val set: {val[:5]}")
print(f"Test set: {test[:5]}")
# Out:
# Train set: ['1000092795.jpg', '10002456.jpg', '1000268201.jpg', '1000344755.jpg', '1000366164.jpg']
# Val set: ['1018148011.jpg', '1029450589.jpg', '1029737941.jpg', '103205630.jpg', '10350842.jpg']
# Test set: ['1007129816.jpg', '1009434119.jpg', '101362133.jpg', '102617084.jpg', '10287332.jpg']

# %%
save_split(train, val, test)
